# %% [markdown]
# #### The Titanic Dataset is Exist in Seaborn Library as 'titanic'.
# #### Titanic's Dataset include many columns :
#    * survived (0 - 1)
#    * pclass (1 if first_class - 2 if second_class - 3 if third_class)
#    * sex (male - female)
#    * age
#    * sibsp (Number of siblings/spouses aboard)
#    * parch (Number of parents/children aboard)
#    * fare (ticket)
#    * embarked (S - Q - C)
#    * class (First - Second - Third)
#    * who (man - women)
#    * adult_male (True - False)
#    * embark_town (Southampton - Queenstown - Cherbourg)
#    * alive (no - yes)
#    * alone (True - False)

# %% [markdown]
# ## Main Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

## For Detecting Outliers
from datasist.structdata import detect_outliers

# %%
## Figure Size and Font Scale
sns.set(rc={'figure.figsize':[8, 8]}, font_scale=1.2)

# %% [markdown]
# ## Loading Dataset

# %%
## Load Dataset using Seaborn
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Exploring the Dataset

# %%
## using method .info() to obtain information about Titanic Dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
## using method .head(10) to show() the fist 10 rows in df
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
## using method .head(10) to show() the last 10 rows in df
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
## create new_column
df['family_size'] = df['sibsp'] + df['parch']

# %%
numerical_columns = ['age','fare','family_size']
categorical_columns = ['sex','sibsp','parch','class','who','alive']

# %%
df[numerical_columns].describe()
# Out:
#               age        fare  family_size
# count  714.000000  891.000000   891.000000
# mean    29.699118   32.204208     0.904602
# std     14.526497   49.693429     1.613459
# min      0.420000    0.000000     0.000000
# 25%     20.125000    7.910400     0.000000
# 50%     28.000000   14.454200     0.000000
# 75%     38.000000   31.000000     1.000000
# max     80.000000  512.329200    10.000000

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Data Cleaning in very Important Step In Exploratory Data Analysis. We must Handling Missing Values and Detecting Outliers.

# %%
## Handling missing value
df.isna().sum()
## Drop useless Columns
df.drop('deck',axis=1,inplace=True)

# %%
## Detect outliers 
outliers_index = detect_outliers(df,0,features=['age','fare'])

# %%
## Drop outliers
df.drop(outliers_index,axis=0,inplace=True)

# %% [markdown]
# ### Data Visualizations

# %% [markdown]
# #### - Data Visualizations help us to show the relation between featuresa
# #### - Data Visualizations help us to understand the data.y.

# %% [markdown]
# #### In this Module there exist many plots using Seaborn library.

# %%
sns.displot(data=df,x='age',hue='alive',multiple='stack');

# %%
sns.kdeplot(data=df,x='age',hue='alive',shade=True);
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_1644\1516026765.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df,x='age',hue='alive',shade=True);

# %%
sns.displot(data=df,x='fare',hue='alive',multiple='stack');

# %%
sns.kdeplot(data=df,x='fare',hue='alive',shade=True);
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_1644\141353798.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df,x='fare',hue='alive',shade=True);

# %%
sns.jointplot(data=df,x='age',y='fare',hue='alive');

# %%
sns.countplot(data=df,x='sex',palette='Set1');
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_1644\1265493617.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='sex',palette='Set1');

# %%
sns.countplot(data=df,x='class',hue='alive',palette='Set1');

# %%
sns.countplot(data=df,x='who',hue='alive',palette='Set1');

# %%
sns.countplot(data=df,x='adult_male',palette='Set1');
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_1644\3968922709.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='adult_male',palette='Set1');

# %%
sns.countplot(data=df,x='embark_town',hue='alive',palette='Set1');

# %%
sns.countplot(data=df,x='alive',palette='Set1');
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_1644\1646049863.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='alive',palette='Set1');

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
sns.boxplot(data=df,x='sex',y='age',palette='Set1',hue='who');

# %%
sns.boxplot(data=df,x='sex',y='age',palette='Set1',hue='class');

# %%
sns.boxplot(data=df,x='sex',y='age',palette='Set1',hue='embark_town');

# %%
sns.boxplot(data=df,x='sex',y='fare',palette='Set1',hue='class');

# %%
sns.boxplot(data=df,x='class',y='age',palette='Set1',hue='who');

# %%
sns.boxplot(data=df,x='class',y='age',palette='Set1',hue='alive');

# %%
sns.boxplot(data=df,x='sex',y='fare',palette='Set1',hue='alive');

# %%
sns.violinplot(data=df,x='class',y='age',palette='Set1',hue='alive',split=True);

# %% [markdown]
# ## Exploring Correlation

# %% [markdown]
# #### To Find Relationship Between Features we using techniques like correlation analysis

# %%
df[numerical_columns].corr()
# Out:
#                   age      fare  family_size
# age          1.000000  0.090865    -0.348148
# fare         0.090865  1.000000     0.422070
# family_size -0.348148  0.422070     1.000000

# %%
sns.heatmap(df[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Thank you for your interest in the project and reaching to this point
